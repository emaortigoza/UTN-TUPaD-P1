# %% [markdown]
# # ✨ Verificación de Números Perfectos
#
# En este notebook veremos cómo determinar si un número natural es **perfecto**.
#
# Un número perfecto es aquel que es igual a la suma de sus divisores propios positivos (excluyendo el mismo número).
#
# Ejemplos clásicos:
# - 6 → 1 + 2 + 3 = 6 ✅
# - 28 → 1 + 2 + 4 + 7 + 14 = 28 ✅

# %% [markdown]
# ## 🔢 Función `leer_entero_validado()`

# %%
def leer_entero_validado(mensaje, min = float("-Inf"), max = float("Inf")):
    n = int(input(f"{mensaje}: "))
    while n < min or n > max:
        n = int(input(f"ERROR. {mensaje}: "))
    return n

# %% [markdown]
# 🔁 Esta función pide al usuario un número entero y repite el pedido hasta que esté dentro del rango permitido.

# %% [markdown]
# ## 🔁 Función `obtener_resto()` (sin `%`)

# %%
def obtener_resto(num1, num2):
    return num1 - num2 * (num1 // num2)

# %% [markdown]
# ✏️ Calcula el resto de una división sin usar el operador `%`.

# %% [markdown]
# ## ✅ Función `es_multiplo()`

# %%
def es_multiplo(x, y):
    return obtener_resto(x, y) == 0

# %% [markdown]
# 📌 Determina si `x` es múltiplo de `y` usando `obtener_resto()`.

# %% [markdown]
# ## ➕ Función `sumatoria_divisores_propios()`

# %%
def sumatoria_divisores_propios(numero):
    sumatoria = 0
    for i in range(1, numero // 2 + 1):
        if es_multiplo(numero, i):
            sumatoria += i
    return sumatoria

# %% [markdown]
# 🧮 Recorre los divisores propios del número (hasta la mitad) y los suma si son divisores.

# %% [markdown]
# ## ✨ Función `es_perfecto()`

# %%
def es_perfecto(numero):
    # Algunos nums perfectos: 6, 28, 496, 8128
    return sumatoria_divisores_propios(numero) == numero

# %% [markdown]
# 🔍 Compara la suma de los divisores propios con el número original para saber si es perfecto.

# %% [markdown]
# ## 📢 Función `informar_si_numero_es_perfecto()`

# %%
def informar_si_numero_es_perfecto(numero):
    if es_perfecto(numero):
        print(f"El numero {numero} es perfecto")
    else:
        print(f"El numero {numero} NO es perfecto")

# %% [markdown]
# 📣 Muestra un mensaje indicando si el número ingresado es perfecto o no.

# %% [markdown]
# ## 🧪 Programa principal

# %%
num = leer_entero_validado("Ingrese un número natural", 1)
informar_si_numero_es_perfecto(num)

# %% [markdown]
# ✅ El usuario ingresa un número natural y el programa informa si es un número perfecto.
